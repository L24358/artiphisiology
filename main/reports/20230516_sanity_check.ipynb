# %% [markdown]
# # Sanity Check of Receptive Field Size Calculations

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_path = f"/home2/belleliu/artiphisiology/graphs/sanitycheck_RF_mdl=AN.png" # this is plotted using code elsewhere
image = mpimg.imread(image_path)
fig = plt.figure(dpi=150)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image_path = f"/home2/belleliu/artiphisiology/graphs/sanitycheck_RF_mdl=VGG16.png" # this is plotted using code elsewhere
image = mpimg.imread(image_path)
fig = plt.figure(dpi=200)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image_path = f"/home2/belleliu/artiphisiology/graphs/sanitycheck_RF_mdl=VGG16b.png" # this is plotted using code elsewhere
image = mpimg.imread(image_path)
fig = plt.figure(dpi=300)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image_path = f"/home2/belleliu/artiphisiology/graphs/sanitycheck_RF_mdl=ResNet18.png" # this is plotted using code elsewhere
image = mpimg.imread(image_path)
fig = plt.figure(dpi=300)
plt.imshow(image)
plt.axis('off')
plt.show()

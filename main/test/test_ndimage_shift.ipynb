# %%
import numpy as np
from PIL import Image

tot_pxl = 1024
image = Image.open(f"/src/data/shapes_uncentered/idx={5}_pxl={tot_pxl}.png")
image_array = np.asarray(image)

# %%
from scipy.ndimage import shift

new_image_array = shift(image_array, [0, 20, 0], mode="nearest")

# %%
image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x1024>

# %%
new_image = Image.fromarray(new_image_array)

# %%
new_image.show()
# Out:
# <PIL.Image.Image image mode=RGBA size=1024x1024>
